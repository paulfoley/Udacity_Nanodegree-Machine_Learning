# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Unsupervised Learning
# ## Project: Creating Customer Segments

# %% [markdown]
# Welcome to the third project of the Machine Learning Engineer Nanodegree! In this notebook, some template code has already been provided for you, and it will be your job to implement the additional functionality necessary to successfully complete this project. Sections that begin with **'Implementation'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `'TODO'` statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ## Getting Started
#
# In this project, you will analyze a dataset containing data on various customers' annual spending amounts (reported in *monetary units*) of diverse product categories for internal structure. One goal of this project is to best describe the variation in the different types of customers that a wholesale distributor interacts with. Doing so would equip the distributor with insight into how to best structure their delivery service to meet the needs of each customer.
#
# The dataset for this project can be found on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Wholesale+customers). For the purposes of this project, the features `'Channel'` and `'Region'` will be excluded in the analysis — with focus instead on the six product categories recorded for customers.
#
# Run the code block below to load the wholesale customers dataset, along with a few of the necessary Python libraries required for this project. You will know the dataset loaded successfully if the size of the dataset is reported.

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
from IPython.display import display # Allows the use of display() for DataFrames

# sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score, silhouette_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# Import supplementary visualizations code visuals.py
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# Load the wholesale customers dataset
try:
    data = pd.read_csv("customers.csv")
    data.drop(['Region', 'Channel'], axis = 1, inplace = True)
    print("Wholesale customers dataset has {} samples with {} features each.".format(*data.shape))
except:
    print("Dataset could not be loaded. Is the dataset missing?")
# Out:
# Wholesale customers dataset has 440 samples with 6 features each.

# %% [markdown]
# ## Data Exploration
# In this section, you will begin exploring the data through visualizations and code to understand how each feature is related to the others. You will observe a statistical description of the dataset, consider the relevance of each feature, and select a few sample data points from the dataset which you will track through the course of this project.
#
# Run the code block below to observe a statistical description of the dataset. Note that the dataset is composed of six important product categories: **'Fresh'**, **'Milk'**, **'Grocery'**, **'Frozen'**, **'Detergents_Paper'**, and **'Delicatessen'**. Consider what each category represents in terms of products you could purchase.

# %%
# Display a description of the dataset
display(data.describe())
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %% [markdown]
# ### Implementation: Selecting Samples
# To get a better understanding of the customers and how their data will transform through the analysis, it would be best to select a few sample data points and explore them in more detail. In the code block below, add **three** indices of your choice to the `indices` list which will represent the customers to track. It is suggested to try different sets of samples until you obtain customers that vary significantly from one another.

# %%
# Select three indices of your choice you wish to sample from the dataset
indices = [1,2,3]

# Create a DataFrame of the chosen samples
samples = pd.DataFrame(data.loc[indices], columns = data.keys()).reset_index(drop = True)
print("Chosen samples of wholesale customers dataset:")
display(samples)
# Out:
# Chosen samples of wholesale customers dataset:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0   7057  9810     9568    1762              3293          1776
# 1   6353  8808     7684    2405              3516          7844
# 2  13265  1196     4221    6404               507          1788

# %% [markdown]
# ### Question 1
# Consider the total purchase cost of each product category and the statistical description of the dataset above for your sample customers.
# *What kind of establishment (customer) could each of the three samples you've chosen represent?*
# **Hint:** Examples of establishments include places like markets, cafes, and retailers, among many others. Avoid using names for establishments, such as saying *"McDonalds"* when describing a sample customer as a restaurant.

# %% [markdown]
# Sample 0 and 1 appear to be coffee shops because they're buying a lot of milk and coffee shops need milk. Also sample 1 appears to be a high end coffee shop as they purchase a lot of delicatessen items. Sample 2 seems to be a more of a restuarant because they buy a lot of fresh and frozen food.

# %% [markdown]
# ### Implementation: Feature Relevance
# One interesting thought to consider is if one (or more) of the six product categories is actually relevant for understanding customer purchasing. That is to say, is it possible to determine whether customers purchasing some amount of one category of products will necessarily purchase some proportional amount of another category of products? We can make this determination quite easily by training a supervised regression learner on a subset of the data with one feature removed, and then score how well that model can predict the removed feature.
#
# In the code block below, you will need to implement the following:
#  - Assign `new_data` a copy of the data by removing a feature of your choice using the `DataFrame.drop` function.
#  - Use `sklearn.cross_validation.train_test_split` to split the dataset into training and testing sets.
#    - Use the removed feature as your target label. Set a `test_size` of `0.25` and set a `random_state`.
#  - Import a decision tree regressor, set a `random_state`, and fit the learner to the training data.
#  - Report the prediction score of the testing set using the regressor's `score` function.

# %%
# Make a copy of the DataFrame, using the 'drop' function to drop the given feature
new_data = data.drop(labels = 'Milk', axis = 1, level = None, inplace = False, errors = 'raise')

# Split the data into training and testing sets using the given feature as the target
X_train, X_test, y_train, y_test = train_test_split(new_data, data['Milk'], test_size=0.25, random_state=42)

# Create a decision tree regressor and fit it to the training set
regressor = DecisionTreeRegressor().fit(X_train, y_train)

# Report the score of the prediction using the testing set
score = regressor.score(X_test, y_test)
score
# Out:
# 0.16865817716232467

# %% [markdown]
# ### Question 2
# *Which feature did you attempt to predict? What was the reported prediction score? Is this feature necessary for identifying customers' spending habits?*
# **Hint:** The coefficient of determination, `R^2`, is scored between 0 and 1, with 1 being a perfect fit. A negative `R^2` implies the model fails to fit the data.

# %% [markdown]
# Interesting! I tried to predict the Milk feature. The reported prediction score was 0.2288, which doesn't give us a high correlation.

# %% [markdown]
# ### Visualize Feature Distributions
# To get a better understanding of the dataset, we can construct a scatter matrix of each of the six product features present in the data. If you found that the feature you attempted to predict above is relevant for identifying a specific customer, then the scatter matrix below may not show any correlation between that feature and the others. Conversely, if you believe that feature is not relevant for identifying a specific customer, the scatter matrix might show a correlation between that feature and another feature in the data. Run the code block below to produce a scatter matrix.

# %%
# Produce a scatter matrix for each pair of features in the data
pd.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %% [markdown]
# ### Question 3
# *Are there any pairs of features which exhibit some degree of correlation? Does this confirm or deny your suspicions about the relevance of the feature you attempted to predict? How is the data for those features distributed?*
# **Hint:** Is the data normally distributed? Where do most of the data points lie?

# %% [markdown]
# So yes there does appear to be some correlation between certain features. Milk Seems to correlate to Detergents_Paper as well as grocery. Grocery seems to correlate to Detergents_Paper.

# %% [markdown]
# ## Data Preprocessing
# In this section, you will preprocess the data to create a better representation of customers by performing a scaling on the data and detecting (and optionally removing) outliers. Preprocessing data is often times a critical step in assuring that results you obtain from your analysis are significant and meaningful.

# %% [markdown]
# ### Implementation: Feature Scaling
# If data is not normally distributed, especially if the mean and median vary significantly (indicating a large skew), it is most [often appropriate](http://econbrowser.com/archives/2014/02/use-of-logarithms-in-economics) to apply a non-linear scaling — particularly for financial data. One way to achieve this scaling is by using a [Box-Cox test](http://scipy.github.io/devdocs/generated/scipy.stats.boxcox.html), which calculates the best power transformation of the data that reduces skewness. A simpler approach which can work in most cases would be applying the natural logarithm.
#
# In the code block below, you will need to implement the following:
#  - Assign a copy of the data to `log_data` after applying logarithmic scaling. Use the `np.log` function for this.
#  - Assign a copy of the sample data to `log_samples` after applying logarithmic scaling. Again, use `np.log`.

# %%
# Scale the data using the natural logarithm
log_data = np.log(data)

# Scale the sample data using the natural logarithm
log_samples = np.log(log_data)

# Produce a scatter matrix for each pair of newly-transformed features
pd.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %% [markdown]
# ### Observation
# After applying a natural logarithm scaling to the data, the distribution of each feature should appear much more normal. For any pairs of features you may have identified earlier as being correlated, observe here whether that correlation is still present (and whether it is now stronger or weaker than before).
#
# Run the code below to see how the sample data has changed after having the natural logarithm applied to it.

# %%
# Display the log-transformed sample data
display(log_samples)
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 0    2.245688  2.216519  2.189501  1.680078          2.065765      1.973933
# 1    2.181747  2.218242  2.215521  2.011458          2.091809      2.012516
# 2    2.169817  2.206450  2.191307  2.052238          2.099866      2.193607
# 3    2.250542  1.958225  2.122001  2.170730          1.829137      2.013416
# 4    2.305218  2.151297  2.183977  2.112945          2.012591      2.146343
# 5    2.213737  2.199340  2.145005  1.872001          2.013937      1.985132
# 6    2.241040  2.088227  2.180427  1.820312          2.085918      1.840674
# 7    2.189768  2.141049  2.213888  2.004176          2.092854      2.060527
# 8    2.162556  2.104370  2.166881  1.800404          2.007912      1.890106
# 9    2.163382  2.231526  2.287056  1.953781          2.187467      2.034541
# 10   2.094512  2.151147  2.248203  2.126964          2.162826      2.010083
# 11   2.249593  1.949425  2.130245  1.982161          1.841834      1.825934
# 12   2.338388  2.242718  2.237748  1.733332          2.111890      2.077327
# 13   2.298834  2.167177  2.263283  2.084123          2.175990      1.856338
# 14   2.313787  2.214339  2.240733  1.737581          2.143440      2.038823
# 15   2.223036  1.948152  2.110003  1.789079          1.927323      1.795257
# 16   1.935507  2.206550  2.240996  1.588794          2.129850      1.943724
# 17   2.160864  2.166232  2.077412  1.906904          1.777238      2.129057
# 18   2.285538  2.169349  2.221396  2.041023          2.070088      2.087528
# 19   2.192693  2.056946  2.214328  1.872692          2.058118      1.827224
# 20   2.279581  2.130140  2.132300  1.941855          2.044161      2.036150
# 21   2.154620  1.912448  2.028923  2.095133          1.779506      1.847491
# 22   2.337045  2.022675  2.128817  2.213679          2.050949      2.125161
# 23   2.320434  2.351657  2.302551  2.145642          2.125244      2.273415
# 24   2.305360  2.217864  2.254638  2.076641          2.129163      2.158924
# 25   2.271157  2.122256  2.190004  1.668330          2.115629      1.397000
# 26   2.219213  1.926869  2.074294  2.086352          1.702735      1.905837
# 27   2.258250  1.900368  2.082095  1.821989          1.527180      1.832578
# 28   2.118892  2.295299  2.318871  1.953659          2.203867      2.146816
# 29   2.367530  2.034665  2.062641  1.958696          1.947253      1.904039
# ..        ...       ...       ...       ...               ...           ...
# 410  2.174730  2.034416  2.131291  1.979115          2.018673      2.020937
# 411  2.036273  2.091659  2.091358  1.992833          1.697373      2.126012
# 412  1.520544  2.102923  2.243414  1.522783          2.078981      1.417583
# 413  2.141687  2.138723  2.174730  2.281428          1.919220      2.053829
# 414  2.162672  2.027607  2.096362  2.156927          1.950811      1.735168
# 415  2.193579  2.164145  2.203198  2.005940          2.100699      2.019669
# 416  2.126666  2.230034  2.229719  1.908487          2.176345      1.931627
# 417  2.143602  2.153194  2.231158  1.774470          2.098781      1.941450
# 418  1.870608  2.202446  2.285652  1.587264          2.176547      1.895241
# 419  2.207111  2.108791  2.042079  1.864153          1.996764      1.991583
# 420  2.128471  2.148154  2.250240  1.169032          2.177852      1.979513
# 421  2.276720  2.138431  2.209466  1.937055          2.096290      2.013117
# 422  2.320535  1.977916  2.120602  1.905300          1.924884      1.960794
# 423  2.279691  2.105633  2.133708  1.940909          2.014531      1.872462
# 424  2.276220  2.075300  2.241965  1.912956          2.088768      1.707916
# 425  2.232967  2.052398  2.061859  2.265790          1.543753      2.020516
# 426  2.249496  2.212968  2.258543  2.085957          2.143926      2.021077
# 427  2.336226  2.274431  2.151705  2.263975          1.805744      1.954269
# 428  2.082177  2.162691  2.139952  2.040610          1.908837      1.750747
# 429  2.203906  2.010543  2.102073  1.348111          1.488584      2.057253
# 430  2.084204  2.122256  2.273165  1.849143          1.701980      2.033414
# 431  2.202952  2.153342  2.145778  2.252282          1.977916      1.989501
# 432  2.298360  1.954147  2.136146  1.721822          1.972890      1.788234
# 433  2.027077  2.088961  1.989044  1.993364          1.770694      1.984943
# 434  2.274702  2.113161  2.195718  1.876987          2.050407      1.906726
# 435  2.332047  2.240380  2.270272  2.249504          1.649429      2.040964
# 436  2.358696  1.983224  1.892896  2.129903          1.511296      2.049043
# 437  2.260099  2.266732  2.333795  1.804994          2.262299      2.019172
# 438  2.223426  2.027010  2.042603  1.938029          1.633928      2.036211
# 439  2.070996  2.006495  2.057712  1.428968          1.819296      1.374030
#
# [440 rows x 6 columns]

# %% [markdown]
# ### Implementation: Outlier Detection
# Detecting outliers in the data is extremely important in the data preprocessing step of any analysis. The presence of outliers can often skew results which take into consideration these data points. There are many "rules of thumb" for what constitutes an outlier in a dataset. Here, we will use [Tukey's Method for identfying outliers](http://datapigtechnologies.com/blog/index.php/highlighting-outliers-in-your-data-with-the-tukey-method/): An *outlier step* is calculated as 1.5 times the interquartile range (IQR). A data point with a feature that is beyond an outlier step outside of the IQR for that feature is considered abnormal.
#
# In the code block below, you will need to implement the following:
#  - Assign the value of the 25th percentile for the given feature to `Q1`. Use `np.percentile` for this.
#  - Assign the value of the 75th percentile for the given feature to `Q3`. Again, use `np.percentile`.
#  - Assign the calculation of an outlier step for the given feature to `step`.
#  - Optionally remove data points from the dataset by adding indices to the `outliers` list.
#
# **NOTE:** If you choose to remove any outliers, ensure that the sample data does not contain any of these points!
# Once you have performed this implementation, the dataset will be stored in the variable `good_data`.

# %%
# For each feature find the data points with extreme high or low values
for feature in log_data.keys():
    # Calculate Q1 (25th percentile of the data) for the given feature
    Q1 = np.percentile(data[feature], 25)
    
    # Calculate Q3 (75th percentile of the data) for the given feature
    Q3 = np.percentile(data[feature], 75)
    
    # Use the interquartile range to calculate an outlier step (1.5 times the interquartile range)
    step = (Q3-Q1) * 1.5
    
    # Display the outliers
    print("Data points considered outliers for the feature '{}':".format(feature))
    display(log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))])
    
# Select the indices for data points you wish to remove
outliers  = []

# Remove the outliers, if any were specified
good_data = log_data.drop(log_data.index[outliers]).reset_index(drop = True)
# Out:
# Data points considered outliers for the feature 'Fresh':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []
# Data points considered outliers for the feature 'Milk':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []
# Data points considered outliers for the feature 'Grocery':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []
# Data points considered outliers for the feature 'Frozen':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []
# Data points considered outliers for the feature 'Detergents_Paper':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []
# Data points considered outliers for the feature 'Delicatessen':
# Empty DataFrame
# Columns: [Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicatessen]
# Index: []

# %% [markdown]
# ### Question 4
# *Are there any data points considered outliers for more than one feature based on the definition above? Should these data points be removed from the dataset? If any data points were added to the `outliers` list to be removed, explain why.*

# %% [markdown]
# Doesn't look like it! Everything came back blank...

# %% [markdown]
# ## Feature Transformation
# In this section you will use principal component analysis (PCA) to draw conclusions about the underlying structure of the wholesale customer data. Since using PCA on a dataset calculates the dimensions which best maximize variance, we will find which compound combinations of features best describe customers.

# %% [markdown]
# ### Implementation: PCA
#
# Now that the data has been scaled to a more normal distribution and has had any necessary outliers removed, we can now apply PCA to the `good_data` to discover which dimensions about the data best maximize the variance of features involved. In addition to finding these dimensions, PCA will also report the *explained variance ratio* of each dimension — how much variance within the data is explained by that dimension alone. Note that a component (dimension) from PCA can be considered a new "feature" of the space, however it is a composition of the original features present in the data.
#
# In the code block below, you will need to implement the following:
#  - Import `sklearn.decomposition.PCA` and assign the results of fitting PCA in six dimensions with `good_data` to `pca`.
#  - Apply a PCA transformation of `log_samples` using `pca.transform`, and assign the results to `pca_samples`.

# %%
# Apply PCA by fitting the good data with the same number of dimensions as features
pca = PCA(n_components = 6).fit(good_data)

# Transform log_samples using the PCA fit above
pca_samples = pca.transform(log_samples)

# Generate PCA results plot
pca_results = vs.pca_results(good_data, pca)

# %% [markdown]
# ### Question 5
# *How much variance in the data is explained* ***in total*** *by the first and second principal component? What about the first four principal components? Using the visualization provided above, discuss what the first four dimensions best represent in terms of customer spending.*
# **Hint:** A positive increase in a specific dimension corresponds with an *increase* of the *positive-weighted* features and a *decrease* of the *negative-weighted* features. The rate of increase or decrease is based on the individual feature weights.

# %% [markdown]
# From the graph Dimension 1 gives an explained variance of 0.4424, Dimension 2 gives an explained variance of 0.2766, Dimension 3 gives an explained variance of 0.1162, and Dimension 4 gives an explained variance of 0.0962. As we can see the explained variance decreases for each dimension, which is what we expected because we figured that we could reduce our features using PCA.

# %% [markdown]
# ### Observation
# Run the code below to see how the log-transformed sample data has changed after having a PCA transformation applied to it in six dimensions. Observe the numerical value for the first four dimensions of the sample points. Consider if this is consistent with your initial interpretation of the sample points.

# %%
# Display sample log-data after having a PCA transformation applied
display(pd.DataFrame(np.round(pca_samples, 4), columns = pca_results.index.values))
# Out:
#      Dimension 1  Dimension 2  Dimension 3  Dimension 4  Dimension 5  \
# 0         7.2952      11.1661       0.7788      -2.1423      -2.6541
# 1         7.3034      11.0254       0.9346      -1.8746      -2.6780
# 2         7.2910      10.9247       1.0696      -1.9324      -2.7363
# 3         7.6836      10.9599       0.9860      -1.8222      -2.7563
# 4         7.4222      10.8395       0.9827      -1.9063      -2.7226
# 5         7.3866      11.0967       0.8744      -1.9995      -2.6619
# 6         7.3781      11.1894       0.7276      -1.9590      -2.7404
# 7         7.3268      11.0116       0.9554      -1.9082      -2.7440
# 8         7.4116      11.2293       0.8247      -1.9990      -2.6983
# 9         7.1780      11.0438       0.9220      -1.9054      -2.6996
# 10        7.2672      11.0358       1.0059      -1.7472      -2.7588
# 11        7.6692      11.1484       0.8087      -1.8750      -2.7235
# 12        7.2383      11.0144       0.7874      -2.1600      -2.6666
# 13        7.2953      10.9908       0.7542      -1.7428      -2.7179
# 14        7.2269      11.0518       0.7724      -2.1258      -2.6965
# 15        7.5819      11.2744       0.7338      -1.9942      -2.7666
# 16        7.1628      11.4339       0.9262      -2.1186      -2.6701
# 17        7.5822      11.0625       1.0654      -2.0839      -2.6053
# 18        7.3482      10.9101       0.9244      -1.9162      -2.7148
# 19        7.3984      11.2077       0.7704      -1.9032      -2.7347
# 20        7.4130      11.0024       0.8743      -1.9799      -2.7459
# 21        7.7760      11.1630       0.9344      -1.7937      -2.7585
# 22        7.4954      10.8025       0.9655      -1.8197      -2.8559
# 23        7.1946      10.7029       1.0419      -1.9157      -2.6261
# 24        7.2688      10.8301       0.9549      -1.9141      -2.7168
# 25        7.3836      11.4616       0.3724      -1.8532      -2.6370
# 26        7.8079      11.0910       0.9418      -1.8560      -2.7002
# 27        7.9179      11.2417       0.8302      -2.0732      -2.5938
# 28        7.1016      11.0038       1.0218      -1.9473      -2.6736
# 29        7.5925      11.0256       0.7550      -1.9420      -2.7594
# ..           ...          ...          ...          ...          ...
# 410       7.4607      11.0805       0.9482      -1.9263      -2.7993
# 411       7.6584      11.1220       1.1864      -2.0021      -2.6117
# 412       7.2357      12.0373       0.8554      -1.8241      -2.6099
# 413       7.5154      10.9231       1.1015      -1.7065      -2.6702
# 414       7.6011      11.1541       0.8384      -1.6489      -2.7288
# 415       7.3238      11.0256       0.9264      -1.8854      -2.7276
# 416       7.2141      11.1482       0.8717      -1.8871      -2.6926
# 417       7.2800      11.2126       0.8428      -2.0199      -2.7010
# 418       7.1051      11.4994       0.9265      -2.0693      -2.6742
# 419       7.4784      11.1244       0.8848      -2.0193      -2.7544
# 420       7.1018      11.4950       0.6871      -2.5080      -2.7280
# 421       7.3379      11.0095       0.8464      -1.9563      -2.7378
# 422       7.5794      11.0611       0.8091      -2.0057      -2.7767
# 423       7.4684      11.0913       0.7741      -1.9026      -2.7144
# 424       7.3950      11.1855       0.6417      -1.8194      -2.7073
# 425       7.8988      10.9228       1.0968      -1.8018      -2.5532
# 426       7.2704      10.9340       0.9028      -1.8209      -2.7006
# 427       7.6026      10.8334       0.9313      -1.7317      -2.4963
# 428       7.5229      11.2348       0.8818      -1.7360      -2.5911
# 429       7.7696      11.3778       0.8881      -2.5629      -2.5122
# 430       7.5577      11.1887       1.0476      -2.0674      -2.5057
# 431       7.4942      10.9253       0.9991      -1.7006      -2.6892
# 432       7.5362      11.2545       0.6488      -2.0505      -2.7751
# 433       7.6709      11.2044       1.0890      -1.9199      -2.6630
# 434       7.3936      11.1014       0.7717      -1.9597      -2.7120
# 435       7.6625      10.8030       1.0151      -1.8097      -2.4079
# 436       8.0212      10.9127       1.0020      -1.9713      -2.6444
# 437       7.0805      11.0458       0.7879      -2.0203      -2.6918
# 438       7.7899      11.0829       1.0001      -2.0566      -2.6202
# 439       7.6377      11.7676       0.4893      -2.0585      -2.5863
#
#      Dimension 6
# 0         1.3214
# 1         1.3016
# 2         1.3121
# 3         1.1786
# 4         1.2665
# 5         1.3351
# 6         1.2639
# 7         1.2600
# 8         1.2694
# 9         1.2710
# 10        1.2536
# 11        1.1772
# 12        1.2997
# 13        1.2509
# 14        1.2897
# 15        1.2152
# 16        1.2984
# 17        1.3219
# 18        1.2606
# 19        1.2145
# 20        1.3097
# 21        1.2273
# 22        1.2471
# 23        1.2976
# 24        1.2690
# 25        1.2925
# 26        1.1796
# 27        1.1285
# 28        1.2818
# 29        1.2951
# ..           ...
# 410       1.2561
# 411       1.2561
# 412       1.2552
# 413       1.2522
# 414       1.2709
# 415       1.2837
# 416       1.3188
# 417       1.2619
# 418       1.2723
# 419       1.3664
# 420       1.2697
# 421       1.2626
# 422       1.2136
# 423       1.2930
# 424       1.2078
# 425       1.2196
# 426       1.2708
# 427       1.3186
# 428       1.3043
# 429       1.1690
# 430       1.1289
# 431       1.2958
# 432       1.2055
# 433       1.3562
# 434       1.2543
# 435       1.1703
# 436       1.3110
# 437       1.2674
# 438       1.2453
# 439       1.2879
#
# [440 rows x 6 columns]

# %% [markdown]
# ### Implementation: Dimensionality Reduction
# When using principal component analysis, one of the main goals is to reduce the dimensionality of the data — in effect, reducing the complexity of the problem. Dimensionality reduction comes at a cost: Fewer dimensions used implies less of the total variance in the data is being explained. Because of this, the *cumulative explained variance ratio* is extremely important for knowing how many dimensions are necessary for the problem. Additionally, if a signifiant amount of variance is explained by only two or three dimensions, the reduced data can be visualized afterwards.
#
# In the code block below, you will need to implement the following:
#  - Assign the results of fitting PCA in two dimensions with `good_data` to `pca`.
#  - Apply a PCA transformation of `good_data` using `pca.transform`, and assign the results to `reduced_data`.
#  - Apply a PCA transformation of `log_samples` using `pca.transform`, and assign the results to `pca_samples`.

# %%
# Apply PCA by fitting the good data with only two dimensions
pca = PCA(n_components = 2).fit(good_data)

# Transform the good data using the PCA fit above
reduced_data = pca.transform(good_data)

# Transform log_samples using the PCA fit above
pca_samples = pca.transform(log_samples)

# Create a DataFrame for the reduced data
reduced_data = pd.DataFrame(reduced_data, columns = ['Dimension 1', 'Dimension 2'])

# %% [markdown]
# ### Observation
# Run the code below to see how the log-transformed sample data has changed after having a PCA transformation applied to it using only two dimensions. Observe how the values for the first two dimensions remains unchanged when compared to a PCA transformation in six dimensions.

# %%
# Display sample log-data after applying PCA transformation in two dimensions
display(pd.DataFrame(np.round(pca_samples, 4), columns = ['Dimension 1', 'Dimension 2']))
# Out:
#      Dimension 1  Dimension 2
# 0         7.2952      11.1661
# 1         7.3034      11.0254
# 2         7.2910      10.9247
# 3         7.6836      10.9599
# 4         7.4222      10.8395
# 5         7.3866      11.0967
# 6         7.3781      11.1894
# 7         7.3268      11.0116
# 8         7.4116      11.2293
# 9         7.1780      11.0438
# 10        7.2672      11.0358
# 11        7.6692      11.1484
# 12        7.2383      11.0144
# 13        7.2953      10.9908
# 14        7.2269      11.0518
# 15        7.5819      11.2744
# 16        7.1628      11.4339
# 17        7.5822      11.0625
# 18        7.3482      10.9101
# 19        7.3984      11.2077
# 20        7.4130      11.0024
# 21        7.7760      11.1630
# 22        7.4954      10.8025
# 23        7.1946      10.7029
# 24        7.2688      10.8301
# 25        7.3836      11.4616
# 26        7.8079      11.0910
# 27        7.9179      11.2417
# 28        7.1016      11.0038
# 29        7.5925      11.0256
# ..           ...          ...
# 410       7.4607      11.0805
# 411       7.6584      11.1220
# 412       7.2357      12.0373
# 413       7.5154      10.9231
# 414       7.6011      11.1541
# 415       7.3238      11.0256
# 416       7.2141      11.1482
# 417       7.2800      11.2126
# 418       7.1051      11.4994
# 419       7.4784      11.1244
# 420       7.1018      11.4950
# 421       7.3379      11.0095
# 422       7.5794      11.0611
# 423       7.4684      11.0913
# 424       7.3950      11.1855
# 425       7.8988      10.9228
# 426       7.2704      10.9340
# 427       7.6026      10.8334
# 428       7.5229      11.2348
# 429       7.7696      11.3778
# 430       7.5577      11.1887
# 431       7.4942      10.9253
# 432       7.5362      11.2545
# 433       7.6709      11.2044
# 434       7.3936      11.1014
# 435       7.6625      10.8030
# 436       8.0212      10.9127
# 437       7.0805      11.0458
# 438       7.7899      11.0829
# 439       7.6377      11.7676
#
# [440 rows x 2 columns]

# %% [markdown]
# ## Visualizing a Biplot
# A biplot is a scatterplot where each data point is represented by its scores along the principal components. The axes are the principal components (in this case `Dimension 1` and `Dimension 2`). In addition, the biplot shows the projection of the original features along the components. A biplot can help us interpret the reduced dimensions of the data, and discover relationships between the principal components and original features.
#
# Run the code cell below to produce a biplot of the reduced-dimension data.

# %%
# Create a biplot
vs.biplot(good_data, reduced_data, pca)

# %% [markdown]
# ### Observation
#
# Once we have the original feature projections (in red), it is easier to interpret the relative position of each data point in the scatterplot. For instance, a point the lower right corner of the figure will likely correspond to a customer that spends a lot on `'Milk'`, `'Grocery'` and `'Detergents_Paper'`, but not so much on the other product categories.
#
# From the biplot, which of the original features are most strongly correlated with the first component? What about those that are associated with the second component? Do these observations agree with the pca_results plot you obtained earlier?
#
# Detergent_Paper, Grocery, and Milk seem to be the most strongly corelated with the first componenet. Fresh, Frozen, and Delicatessen seem to be the most associated with the second component. This seems in line with the first plot we made with 6 dimensions where those same labels correlated with the first two dimensions.

# %% [markdown]
# ## Clustering
#
# In this section, you will choose to use either a K-Means clustering algorithm or a Gaussian Mixture Model clustering algorithm to identify the various customer segments hidden in the data. You will then recover specific data points from the clusters to understand their significance by transforming them back into their original dimension and scale.

# %% [markdown]
# ### Question 6
# *What are the advantages to using a K-Means clustering algorithm? What are the advantages to using a Gaussian Mixture Model clustering algorithm? Given your observations about the wholesale customer data so far, which of the two algorithms will you use and why?*

# %% [markdown]
# K-Means Advantages :
#
# * If there is a large amount of features, then  K-Means is often computationally faster than hierarchical clustering, if we keep k smalls.
# * K-Means produce tighter clusters than hierarchical clustering.
#
# K-Means Disadvantages :
#
# * Difficult to predict K-Value, and often needs guess and check.
# * Different initial partitions can result in different final clusters.
# * Doesn't work well with clusters of different sizes and different densities.
#
# Gaussian Mixture Model Advantages:
#
# * A lot more flexible in terms of cluster covariance.
# * k-means is actually a special case of GMM in which each cluster’s covariance along all dimensions approaches 0. This implies that a point will get assigned only to the cluster closest to it.
# * With GMM, each cluster can have unconstrained covariance structure.
# * GMM structure makes it more flexible than in k-means.
#
# Gaussian Mixture Model Disadvantages:
#
# * GMM's can Cconverge to local optimal which will give inaccurate results
# * Computationally more expensive if the number of features or distributions is large
# * Needs a large data sets
# * Hard to estimate the number of clusters

# %% [markdown]
# ### Implementation: Creating Clusters
# Depending on the problem, the number of clusters that you expect to be in the data may already be known. When the number of clusters is not known *a priori*, there is no guarantee that a given number of clusters best segments the data, since it is unclear what structure exists in the data — if any. However, we can quantify the "goodness" of a clustering by calculating each data point's *silhouette coefficient*. The [silhouette coefficient](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html) for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar). Calculating the *mean* silhouette coefficient provides for a simple scoring method of a given clustering.
#
# In the code block below, you will need to implement the following:
#  - Fit a clustering algorithm to the `reduced_data` and assign it to `clusterer`.
#  - Predict the cluster for each data point in `reduced_data` using `clusterer.predict` and assign them to `preds`.
#  - Find the cluster centers using the algorithm's respective attribute and assign them to `centers`.
#  - Predict the cluster for each sample data point in `pca_samples` and assign them `sample_preds`.
#  - Import `sklearn.metrics.silhouette_score` and calculate the silhouette score of `reduced_data` against `preds`.
#    - Assign the silhouette score to `score` and print the result.

# %%
# Apply your clustering algorithm of choice to the reduced data 
clusterer = KMeans().fit(reduced_data)

# Predict the cluster for each data point
preds = clusterer.predict(reduced_data)

# Find the cluster centers
centers = clusterer.cluster_centers_

# Predict the cluster for each transformed sample data point
sample_preds = clusterer.predict(pca_samples)

# Calculate the mean silhouette coefficient for the number of clusters chosen
score = silhouette_score(reduced_data, preds)

print(score)
# Out:
# 0.35784307256

# %% [markdown]
# ### Question 7
# *Report the silhouette score for several cluster numbers you tried. Of these, which number of clusters has the best silhouette score?*

# %% [markdown]
# Silhouette Score = 0.354530597852

# %% [markdown]
# ### Cluster Visualization
# Once you've chosen the optimal number of clusters for your clustering algorithm using the scoring metric above, you can now visualize the results by executing the code block below. Note that, for experimentation purposes, you are welcome to adjust the number of clusters for your clustering algorithm to see various visualizations. The final visualization provided should, however, correspond with the optimal number of clusters.

# %%
# Display the results of the clustering from implementation
vs.cluster_results(reduced_data, preds, centers, pca_samples)

# %% [markdown]
# ### Implementation: Data Recovery
# Each cluster present in the visualization above has a central point. These centers (or means) are not specifically data points from the data, but rather the *averages* of all the data points predicted in the respective clusters. For the problem of creating customer segments, a cluster's center point corresponds to *the average customer of that segment*. Since the data is currently reduced in dimension and scaled by a logarithm, we can recover the representative customer spending from these data points by applying the inverse transformations.
#
# In the code block below, you will need to implement the following:
#  - Apply the inverse transform to `centers` using `pca.inverse_transform` and assign the new centers to `log_centers`.
#  - Apply the inverse function of `np.log` to `log_centers` using `np.exp` and assign the true centers to `true_centers`.

# %%
# Inverse transform the centers
log_centers = pca.inverse_transform(centers)

# Exponentiate the centers
true_centers = np.exp(log_centers)

# Display the true centers
segments = ['Segment {}'.format(i) for i in range(0,len(centers))]
true_centers = pd.DataFrame(np.round(true_centers), columns = data.keys())
true_centers.index = segments
display(true_centers)
# Out:
#              Fresh     Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# Segment 0  29722.0   5384.0   6041.0  4480.0            1155.0        2684.0
# Segment 1   1072.0   7723.0  14972.0   370.0            6920.0         473.0
# Segment 2   4759.0   1518.0   2038.0  1334.0             244.0         404.0
# Segment 3   5394.0    475.0    567.0  1666.0              31.0         207.0
# Segment 4   7368.0  10684.0  15769.0  1482.0            6188.0        1822.0
# Segment 5    188.0   1600.0   3568.0   122.0             829.0          62.0
# Segment 6  16815.0   1967.0   2217.0  3291.0             246.0        1006.0
# Segment 7   4937.0   3556.0   5097.0  1247.0            1055.0         711.0

# %% [markdown]
# ### Question 8
# Consider the total purchase cost of each product category for the representative data points above, and reference the statistical description of the dataset at the beginning of this project. *What set of establishments could each of the customer segments represent?*
# **Hint:** A customer who is assigned to `'Cluster X'` should best identify with the establishments represented by the feature set of `'Segment X'`.

# %% [markdown]
# Segment 0: Buys a lot of Milk, Groceries and Delicatessen's
#
# Segment 1: Doesn't buy a lot of anything
#
# Segment 2: Buys a lot of Fresh, Frozen, and Delicatessen
#
# Segment 3: Buys a small amount of everything
#
# Segment 4: Buys a lot of Milk, Grocery, and Detergents_Paper
#
# Segment 5: Doesn't buy much
#
# Segment 6: Doesn't buy much
#
# Segment 7: Buys Fresh, Frozen, and Delicatessen

# %% [markdown]
# ### Question 9
# *For each sample point, which customer segment from* ***Question 8*** *best represents it? Are the predictions for each sample point consistent with this?*
#
# Run the code block below to find which cluster each sample point is predicted to be.

# %%
# Display the predictions
for i, pred in enumerate(sample_preds):
    print("Sample point", i, "predicted to be in Cluster", pred)
# Out:
# Sample point 0 predicted to be in Cluster 5
# Sample point 1 predicted to be in Cluster 5
# Sample point 2 predicted to be in Cluster 5
# Sample point 3 predicted to be in Cluster 5
# Sample point 4 predicted to be in Cluster 5
# Sample point 5 predicted to be in Cluster 5
# Sample point 6 predicted to be in Cluster 5
# Sample point 7 predicted to be in Cluster 5
# Sample point 8 predicted to be in Cluster 5
# Sample point 9 predicted to be in Cluster 5
# Sample point 10 predicted to be in Cluster 5
# Sample point 11 predicted to be in Cluster 5
# Sample point 12 predicted to be in Cluster 5
# Sample point 13 predicted to be in Cluster 5
# Sample point 14 predicted to be in Cluster 5
# Sample point 15 predicted to be in Cluster 5
# Sample point 16 predicted to be in Cluster 5
# Sample point 17 predicted to be in Cluster 5
# Sample point 18 predicted to be in Cluster 5
# Sample point 19 predicted to be in Cluster 5
# Sample point 20 predicted to be in Cluster 5
# Sample point 21 predicted to be in Cluster 5
# Sample point 22 predicted to be in Cluster 5
# Sample point 23 predicted to be in Cluster 5
# Sample point 24 predicted to be in Cluster 5
# Sample point 25 predicted to be in Cluster 5
# Sample point 26 predicted to be in Cluster 5
# Sample point 27 predicted to be in Cluster 5
# Sample point 28 predicted to be in Cluster 5
# Sample point 29 predicted to be in Cluster 5
# Sample point 30 predicted to be in Cluster 5
# Sample point 31 predicted to be in Cluster 5
# Sample point 32 predicted to be in Cluster 5
# Sample point 33 predicted to be in Cluster 5
# Sample point 34 predicted to be in Cluster 5
# Sample point 35 predicted to be in Cluster 5
# Sample point 36 predicted to be in Cluster 5
# Sample point 37 predicted to be in Cluster 5
# Sample point 38 predicted to be in Cluster 5
# Sample point 39 predicted to be in Cluster 5
# Sample point 40 predicted to be in Cluster 5
# Sample point 41 predicted to be in Cluster 5
# Sample point 42 predicted to be in Cluster 5
# Sample point 43 predicted to be in Cluster 5
# Sample point 44 predicted to be in Cluster 5
# Sample point 45 predicted to be in Cluster 5
# Sample point 46 predicted to be in Cluster 5
# Sample point 47 predicted to be in Cluster 5
# Sample point 48 predicted to be in Cluster 5
# Sample point 49 predicted to be in Cluster 5
# Sample point 50 predicted to be in Cluster 5
# Sample point 51 predicted to be in Cluster 5
# Sample point 52 predicted to be in Cluster 5
# Sample point 53 predicted to be in Cluster 5
# Sample point 54 predicted to be in Cluster 5
# Sample point 55 predicted to be in Cluster 5
# Sample point 56 predicted to be in Cluster 5
# Sample point 57 predicted to be in Cluster 5
# Sample point 58 predicted to be in Cluster 5
# Sample point 59 predicted to be in Cluster 5
# Sample point 60 predicted to be in Cluster 5
# Sample point 61 predicted to be in Cluster 5
# Sample point 62 predicted to be in Cluster 5
# Sample point 63 predicted to be in Cluster 5
# Sample point 64 predicted to be in Cluster 5
# Sample point 65 predicted to be in Cluster 5
# Sample point 66 predicted to be in Cluster 5
# Sample point 67 predicted to be in Cluster 5
# Sample point 68 predicted to be in Cluster 5
# Sample point 69 predicted to be in Cluster 5
# Sample point 70 predicted to be in Cluster 5
# Sample point 71 predicted to be in Cluster 5
# Sample point 72 predicted to be in Cluster 5
# Sample point 73 predicted to be in Cluster 5
# Sample point 74 predicted to be in Cluster 5
# Sample point 75 predicted to be in Cluster 3
# Sample point 76 predicted to be in Cluster 5
# Sample point 77 predicted to be in Cluster 5
# Sample point 78 predicted to be in Cluster 5
# Sample point 79 predicted to be in Cluster 5
# Sample point 80 predicted to be in Cluster 5
# Sample point 81 predicted to be in Cluster 5
# Sample point 82 predicted to be in Cluster 5
# Sample point 83 predicted to be in Cluster 5
# Sample point 84 predicted to be in Cluster 5
# Sample point 85 predicted to be in Cluster 5
# Sample point 86 predicted to be in Cluster 5
# Sample point 87 predicted to be in Cluster 5
# Sample point 88 predicted to be in Cluster 5
# Sample point 89 predicted to be in Cluster 5
# Sample point 90 predicted to be in Cluster 5
# Sample point 91 predicted to be in Cluster 5
# Sample point 92 predicted to be in Cluster 5
# Sample point 93 predicted to be in Cluster 5
# Sample point 94 predicted to be in Cluster 5
# Sample point 95 predicted to be in Cluster 5
# Sample point 96 predicted to be in Cluster 5
# Sample point 97 predicted to be in Cluster 5
# Sample point 98 predicted to be in Cluster 5
# Sample point 99 predicted to be in Cluster 5
# Sample point 100 predicted to be in Cluster 5
# Sample point 101 predicted to be in Cluster 5
# Sample point 102 predicted to be in Cluster 5
# Sample point 103 predicted to be in Cluster 5
# Sample point 104 predicted to be in Cluster 5
# Sample point 105 predicted to be in Cluster 5
# Sample point 106 predicted to be in Cluster 5
# Sample point 107 predicted to be in Cluster 5
# Sample point 108 predicted to be in Cluster 5
# Sample point 109 predicted to be in Cluster 5
# Sample point 110 predicted to be in Cluster 5
# Sample point 111 predicted to be in Cluster 5
# Sample point 112 predicted to be in Cluster 5
# Sample point 113 predicted to be in Cluster 5
# Sample point 114 predicted to be in Cluster 5
# Sample point 115 predicted to be in Cluster 5
# Sample point 116 predicted to be in Cluster 5
# Sample point 117 predicted to be in Cluster 5
# Sample point 118 predicted to be in Cluster 5
# Sample point 119 predicted to be in Cluster 5
# Sample point 120 predicted to be in Cluster 5
# Sample point 121 predicted to be in Cluster 5
# Sample point 122 predicted to be in Cluster 5
# Sample point 123 predicted to be in Cluster 5
# Sample point 124 predicted to be in Cluster 5
# Sample point 125 predicted to be in Cluster 5
# Sample point 126 predicted to be in Cluster 5
# Sample point 127 predicted to be in Cluster 5
# Sample point 128 predicted to be in Cluster 5
# Sample point 129 predicted to be in Cluster 5
# Sample point 130 predicted to be in Cluster 5
# Sample point 131 predicted to be in Cluster 5
# Sample point 132 predicted to be in Cluster 5
# Sample point 133 predicted to be in Cluster 5
# Sample point 134 predicted to be in Cluster 5
# Sample point 135 predicted to be in Cluster 5
# Sample point 136 predicted to be in Cluster 5
# Sample point 137 predicted to be in Cluster 5
# Sample point 138 predicted to be in Cluster 5
# Sample point 139 predicted to be in Cluster 5
# Sample point 140 predicted to be in Cluster 5
# Sample point 141 predicted to be in Cluster 5
# Sample point 142 predicted to be in Cluster 5
# Sample point 143 predicted to be in Cluster 5
# Sample point 144 predicted to be in Cluster 5
# Sample point 145 predicted to be in Cluster 5
# Sample point 146 predicted to be in Cluster 5
# Sample point 147 predicted to be in Cluster 5
# Sample point 148 predicted to be in Cluster 5
# Sample point 149 predicted to be in Cluster 5
# Sample point 150 predicted to be in Cluster 5
# Sample point 151 predicted to be in Cluster 5
# Sample point 152 predicted to be in Cluster 5
# Sample point 153 predicted to be in Cluster 5
# Sample point 154 predicted to be in Cluster 5
# Sample point 155 predicted to be in Cluster 5
# Sample point 156 predicted to be in Cluster 5
# Sample point 157 predicted to be in Cluster 5
# Sample point 158 predicted to be in Cluster 5
# Sample point 159 predicted to be in Cluster 5
# Sample point 160 predicted to be in Cluster 5
# Sample point 161 predicted to be in Cluster 3
# Sample point 162 predicted to be in Cluster 5
# Sample point 163 predicted to be in Cluster 5
# Sample point 164 predicted to be in Cluster 5
# Sample point 165 predicted to be in Cluster 5
# Sample point 166 predicted to be in Cluster 5
# Sample point 167 predicted to be in Cluster 5
# Sample point 168 predicted to be in Cluster 5
# Sample point 169 predicted to be in Cluster 5
# Sample point 170 predicted to be in Cluster 5
# Sample point 171 predicted to be in Cluster 5
# Sample point 172 predicted to be in Cluster 5
# Sample point 173 predicted to be in Cluster 5
# Sample point 174 predicted to be in Cluster 5
# Sample point 175 predicted to be in Cluster 5
# Sample point 176 predicted to be in Cluster 5
# Sample point 177 predicted to be in Cluster 5
# Sample point 178 predicted to be in Cluster 5
# Sample point 179 predicted to be in Cluster 5
# Sample point 180 predicted to be in Cluster 5
# Sample point 181 predicted to be in Cluster 5
# Sample point 182 predicted to be in Cluster 5
# Sample point 183 predicted to be in Cluster 5
# Sample point 184 predicted to be in Cluster 5
# Sample point 185 predicted to be in Cluster 5
# Sample point 186 predicted to be in Cluster 5
# Sample point 187 predicted to be in Cluster 5
# Sample point 188 predicted to be in Cluster 5
# Sample point 189 predicted to be in Cluster 5
# Sample point 190 predicted to be in Cluster 5
# Sample point 191 predicted to be in Cluster 5
# Sample point 192 predicted to be in Cluster 5
# Sample point 193 predicted to be in Cluster 5
# Sample point 194 predicted to be in Cluster 5
# Sample point 195 predicted to be in Cluster 5
# Sample point 196 predicted to be in Cluster 5
# Sample point 197 predicted to be in Cluster 5
# Sample point 198 predicted to be in Cluster 5
# Sample point 199 predicted to be in Cluster 5
# Sample point 200 predicted to be in Cluster 5
# Sample point 201 predicted to be in Cluster 5
# Sample point 202 predicted to be in Cluster 5
# Sample point 203 predicted to be in Cluster 5
# Sample point 204 predicted to be in Cluster 5
# Sample point 205 predicted to be in Cluster 5
# Sample point 206 predicted to be in Cluster 5
# Sample point 207 predicted to be in Cluster 5
# Sample point 208 predicted to be in Cluster 5
# Sample point 209 predicted to be in Cluster 5
# Sample point 210 predicted to be in Cluster 5
# Sample point 211 predicted to be in Cluster 5
# Sample point 212 predicted to be in Cluster 5
# Sample point 213 predicted to be in Cluster 5
# Sample point 214 predicted to be in Cluster 5
# Sample point 215 predicted to be in Cluster 5
# Sample point 216 predicted to be in Cluster 5
# Sample point 217 predicted to be in Cluster 5
# Sample point 218 predicted to be in Cluster 5
# Sample point 219 predicted to be in Cluster 5
# Sample point 220 predicted to be in Cluster 5
# Sample point 221 predicted to be in Cluster 5
# Sample point 222 predicted to be in Cluster 5
# Sample point 223 predicted to be in Cluster 5
# Sample point 224 predicted to be in Cluster 5
# Sample point 225 predicted to be in Cluster 5
# Sample point 226 predicted to be in Cluster 5
# Sample point 227 predicted to be in Cluster 5
# Sample point 228 predicted to be in Cluster 5
# Sample point 229 predicted to be in Cluster 5
# Sample point 230 predicted to be in Cluster 5
# Sample point 231 predicted to be in Cluster 5
# Sample point 232 predicted to be in Cluster 5
# Sample point 233 predicted to be in Cluster 5
# Sample point 234 predicted to be in Cluster 5
# Sample point 235 predicted to be in Cluster 5
# Sample point 236 predicted to be in Cluster 5
# Sample point 237 predicted to be in Cluster 5
# Sample point 238 predicted to be in Cluster 5
# Sample point 239 predicted to be in Cluster 5
# Sample point 240 predicted to be in Cluster 5
# Sample point 241 predicted to be in Cluster 5
# Sample point 242 predicted to be in Cluster 5
# Sample point 243 predicted to be in Cluster 5
# Sample point 244 predicted to be in Cluster 5
# Sample point 245 predicted to be in Cluster 5
# Sample point 246 predicted to be in Cluster 5
# Sample point 247 predicted to be in Cluster 5
# Sample point 248 predicted to be in Cluster 5
# Sample point 249 predicted to be in Cluster 5
# Sample point 250 predicted to be in Cluster 5
# Sample point 251 predicted to be in Cluster 5
# Sample point 252 predicted to be in Cluster 5
# Sample point 253 predicted to be in Cluster 5
# Sample point 254 predicted to be in Cluster 5
# Sample point 255 predicted to be in Cluster 5
# Sample point 256 predicted to be in Cluster 5
# Sample point 257 predicted to be in Cluster 5
# Sample point 258 predicted to be in Cluster 5
# Sample point 259 predicted to be in Cluster 5
# Sample point 260 predicted to be in Cluster 5
# Sample point 261 predicted to be in Cluster 5
# Sample point 262 predicted to be in Cluster 5
# Sample point 263 predicted to be in Cluster 5
# Sample point 264 predicted to be in Cluster 5
# Sample point 265 predicted to be in Cluster 5
# Sample point 266 predicted to be in Cluster 5
# Sample point 267 predicted to be in Cluster 5
# Sample point 268 predicted to be in Cluster 5
# Sample point 269 predicted to be in Cluster 5
# Sample point 270 predicted to be in Cluster 5
# Sample point 271 predicted to be in Cluster 5
# Sample point 272 predicted to be in Cluster 5
# Sample point 273 predicted to be in Cluster 5
# Sample point 274 predicted to be in Cluster 5
# Sample point 275 predicted to be in Cluster 5
# Sample point 276 predicted to be in Cluster 5
# Sample point 277 predicted to be in Cluster 5
# Sample point 278 predicted to be in Cluster 5
# Sample point 279 predicted to be in Cluster 5
# Sample point 280 predicted to be in Cluster 5
# Sample point 281 predicted to be in Cluster 5
# Sample point 282 predicted to be in Cluster 5
# Sample point 283 predicted to be in Cluster 5
# Sample point 284 predicted to be in Cluster 5
# Sample point 285 predicted to be in Cluster 5
# Sample point 286 predicted to be in Cluster 5
# Sample point 287 predicted to be in Cluster 5
# Sample point 288 predicted to be in Cluster 5
# Sample point 289 predicted to be in Cluster 5
# Sample point 290 predicted to be in Cluster 5
# Sample point 291 predicted to be in Cluster 5
# Sample point 292 predicted to be in Cluster 5
# Sample point 293 predicted to be in Cluster 5
# Sample point 294 predicted to be in Cluster 5
# Sample point 295 predicted to be in Cluster 5
# Sample point 296 predicted to be in Cluster 5
# Sample point 297 predicted to be in Cluster 5
# Sample point 298 predicted to be in Cluster 5
# Sample point 299 predicted to be in Cluster 5
# Sample point 300 predicted to be in Cluster 5
# Sample point 301 predicted to be in Cluster 5
# Sample point 302 predicted to be in Cluster 5
# Sample point 303 predicted to be in Cluster 5
# Sample point 304 predicted to be in Cluster 5
# Sample point 305 predicted to be in Cluster 5
# Sample point 306 predicted to be in Cluster 5
# Sample point 307 predicted to be in Cluster 5
# Sample point 308 predicted to be in Cluster 5
# Sample point 309 predicted to be in Cluster 5
# Sample point 310 predicted to be in Cluster 5
# Sample point 311 predicted to be in Cluster 5
# Sample point 312 predicted to be in Cluster 5
# Sample point 313 predicted to be in Cluster 5
# Sample point 314 predicted to be in Cluster 5
# Sample point 315 predicted to be in Cluster 5
# Sample point 316 predicted to be in Cluster 5
# Sample point 317 predicted to be in Cluster 5
# Sample point 318 predicted to be in Cluster 5
# Sample point 319 predicted to be in Cluster 5
# Sample point 320 predicted to be in Cluster 5
# Sample point 321 predicted to be in Cluster 5
# Sample point 322 predicted to be in Cluster 5
# Sample point 323 predicted to be in Cluster 5
# Sample point 324 predicted to be in Cluster 5
# Sample point 325 predicted to be in Cluster 5
# Sample point 326 predicted to be in Cluster 5
# Sample point 327 predicted to be in Cluster 5
# Sample point 328 predicted to be in Cluster 5
# Sample point 329 predicted to be in Cluster 5
# Sample point 330 predicted to be in Cluster 5
# Sample point 331 predicted to be in Cluster 5
# Sample point 332 predicted to be in Cluster 5
# Sample point 333 predicted to be in Cluster 5
# Sample point 334 predicted to be in Cluster 5
# Sample point 335 predicted to be in Cluster 5
# Sample point 336 predicted to be in Cluster 5
# Sample point 337 predicted to be in Cluster 5
# Sample point 338 predicted to be in Cluster 5
# Sample point 339 predicted to be in Cluster 5
# Sample point 340 predicted to be in Cluster 5
# Sample point 341 predicted to be in Cluster 5
# Sample point 342 predicted to be in Cluster 5
# Sample point 343 predicted to be in Cluster 5
# Sample point 344 predicted to be in Cluster 5
# Sample point 345 predicted to be in Cluster 5
# Sample point 346 predicted to be in Cluster 5
# Sample point 347 predicted to be in Cluster 5
# Sample point 348 predicted to be in Cluster 5
# Sample point 349 predicted to be in Cluster 5
# Sample point 350 predicted to be in Cluster 5
# Sample point 351 predicted to be in Cluster 5
# Sample point 352 predicted to be in Cluster 5
# Sample point 353 predicted to be in Cluster 5
# Sample point 354 predicted to be in Cluster 5
# Sample point 355 predicted to be in Cluster 5
# Sample point 356 predicted to be in Cluster 3
# Sample point 357 predicted to be in Cluster 5
# Sample point 358 predicted to be in Cluster 5
# Sample point 359 predicted to be in Cluster 5
# Sample point 360 predicted to be in Cluster 5
# Sample point 361 predicted to be in Cluster 5
# Sample point 362 predicted to be in Cluster 5
# Sample point 363 predicted to be in Cluster 5
# Sample point 364 predicted to be in Cluster 5
# Sample point 365 predicted to be in Cluster 5
# Sample point 366 predicted to be in Cluster 5
# Sample point 367 predicted to be in Cluster 5
# Sample point 368 predicted to be in Cluster 5
# Sample point 369 predicted to be in Cluster 5
# Sample point 370 predicted to be in Cluster 5
# Sample point 371 predicted to be in Cluster 5
# Sample point 372 predicted to be in Cluster 5
# Sample point 373 predicted to be in Cluster 5
# Sample point 374 predicted to be in Cluster 5
# Sample point 375 predicted to be in Cluster 5
# Sample point 376 predicted to be in Cluster 5
# Sample point 377 predicted to be in Cluster 5
# Sample point 378 predicted to be in Cluster 5
# Sample point 379 predicted to be in Cluster 5
# Sample point 380 predicted to be in Cluster 5
# Sample point 381 predicted to be in Cluster 5
# Sample point 382 predicted to be in Cluster 5
# Sample point 383 predicted to be in Cluster 5
# Sample point 384 predicted to be in Cluster 5
# Sample point 385 predicted to be in Cluster 5
# Sample point 386 predicted to be in Cluster 5
# Sample point 387 predicted to be in Cluster 5
# Sample point 388 predicted to be in Cluster 5
# Sample point 389 predicted to be in Cluster 5
# Sample point 390 predicted to be in Cluster 5
# Sample point 391 predicted to be in Cluster 5
# Sample point 392 predicted to be in Cluster 5
# Sample point 393 predicted to be in Cluster 5
# Sample point 394 predicted to be in Cluster 5
# Sample point 395 predicted to be in Cluster 5
# Sample point 396 predicted to be in Cluster 5
# Sample point 397 predicted to be in Cluster 5
# Sample point 398 predicted to be in Cluster 5
# Sample point 399 predicted to be in Cluster 5
# Sample point 400 predicted to be in Cluster 5
# Sample point 401 predicted to be in Cluster 5
# Sample point 402 predicted to be in Cluster 5
# Sample point 403 predicted to be in Cluster 5
# Sample point 404 predicted to be in Cluster 5
# Sample point 405 predicted to be in Cluster 5
# Sample point 406 predicted to be in Cluster 5
# Sample point 407 predicted to be in Cluster 5
# Sample point 408 predicted to be in Cluster 5
# Sample point 409 predicted to be in Cluster 5
# Sample point 410 predicted to be in Cluster 5
# Sample point 411 predicted to be in Cluster 5
# Sample point 412 predicted to be in Cluster 5
# Sample point 413 predicted to be in Cluster 5
# Sample point 414 predicted to be in Cluster 5
# Sample point 415 predicted to be in Cluster 5
# Sample point 416 predicted to be in Cluster 5
# Sample point 417 predicted to be in Cluster 5
# Sample point 418 predicted to be in Cluster 5
# Sample point 419 predicted to be in Cluster 5
# Sample point 420 predicted to be in Cluster 5
# Sample point 421 predicted to be in Cluster 5
# Sample point 422 predicted to be in Cluster 5
# Sample point 423 predicted to be in Cluster 5
# Sample point 424 predicted to be in Cluster 5
# Sample point 425 predicted to be in Cluster 5
# Sample point 426 predicted to be in Cluster 5
# Sample point 427 predicted to be in Cluster 5
# Sample point 428 predicted to be in Cluster 5
# Sample point 429 predicted to be in Cluster 5
# Sample point 430 predicted to be in Cluster 5
# Sample point 431 predicted to be in Cluster 5
# Sample point 432 predicted to be in Cluster 5
# Sample point 433 predicted to be in Cluster 5
# Sample point 434 predicted to be in Cluster 5
# Sample point 435 predicted to be in Cluster 5
# Sample point 436 predicted to be in Cluster 5
# Sample point 437 predicted to be in Cluster 5
# Sample point 438 predicted to be in Cluster 5
# Sample point 439 predicted to be in Cluster 5

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this final section, you will investigate ways that you can make use of the clustered data. First, you will consider how the different groups of customers, the ***customer segments***, may be affected differently by a specific delivery scheme. Next, you will consider how giving a label to each customer (which *segment* that customer belongs to) can provide for additional features about the customer data. Finally, you will compare the ***customer segments*** to a hidden variable present in the data, to see whether the clustering identified certain relationships.

# %% [markdown]
# ### Question 10
# Companies will often run [A/B tests](https://en.wikipedia.org/wiki/A/B_testing) when making small changes to their products or services to determine whether making that change will affect its customers positively or negatively. The wholesale distributor is considering changing its delivery service from currently 5 days a week to 3 days a week. However, the distributor will only make this change in delivery service for customers that react positively. *How can the wholesale distributor use the customer segments to determine which customers, if any, would react positively to the change in delivery service?*
# **Hint:** Can we assume the change affects all customers equally? How can we determine which group of customers it affects the most?

# %% [markdown]
# Delivery should only effect goods that need to be delivered in a timely fashion. Off the top of my head, there are certain items that go bad that will need to be delivered constantly, in this case those are fresh, milk, and potentially delicattessen. Customers who are buying non-perishable items won't, potentially, be effected by a change in deliveries as much because they could just order more.

# %% [markdown]
# ### Question 11
# Additional structure is derived from originally unlabeled data when using clustering techniques. Since each customer has a ***customer segment*** it best identifies with (depending on the clustering algorithm applied), we can consider *'customer segment'* as an **engineered feature** for the data. Assume the wholesale distributor recently acquired ten new customers and each provided estimates for anticipated annual spending of each product category. Knowing these estimates, the wholesale distributor wants to classify each new customer to a ***customer segment*** to determine the most appropriate delivery service.
# *How can the wholesale distributor label the new customers using only their estimated product spending and the* ***customer segment*** *data?*
# **Hint:** A supervised learner could be used to train on the original customers. What would be the target variable?

# %% [markdown]
# What we could do now that we have these new segements is we could apply labels to them saying if the change in delivery effects them (1) or doesn't effect them (0). We could then run a supervised learning algorithm and start classifying which segments are effected. Then when a new customer gets acquired we can do our unsupervised learning, segment them, and then determine whether they should be 5 day a week delivery or 3 day a week.

# %% [markdown]
# ### Visualizing Underlying Distributions
#
# At the beginning of this project, it was discussed that the `'Channel'` and `'Region'` features would be excluded from the dataset so that the customer product categories were emphasized in the analysis. By reintroducing the `'Channel'` feature to the dataset, an interesting structure emerges when considering the same PCA dimensionality reduction applied earlier to the original dataset.
#
# Run the code block below to see how each data point is labeled either `'HoReCa'` (Hotel/Restaurant/Cafe) or `'Retail'` the reduced space. In addition, you will find the sample points are circled in the plot, which will identify their labeling.

# %%
# Display the clustering results based on 'Channel' data
vs.channel_results(reduced_data, outliers, pca_samples)

# %% [markdown]
# ### Question 12
# *How well does the clustering algorithm and number of clusters you've chosen compare to this underlying distribution of Hotel/Restaurant/Cafe customers to Retailer customers? Are there customer segments that would be classified as purely 'Retailers' or 'Hotels/Restaurants/Cafes' by this distribution? Would you consider these classifications as consistent with your previous definition of the customer segments?*

# %% [markdown]
# Interesting! The 7 segments that were created do an ok job of clustering, because they do break up the data into clusters similar to the split we see above.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
